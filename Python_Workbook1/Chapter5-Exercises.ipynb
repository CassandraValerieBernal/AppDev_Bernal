# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Investigate on the difference between `is` and `==` given the following variables.
# ```python
# a = 2
# b = 2.0
# c = a
# ```

# %%
a = 2
b = 2.0
c = a

if a == 2:
 print('It is the same')

print(a is c)
a is c


# is you use "==" it is for condition statement
# while, "is" is used to check if the 2 variables have the same value and it will return a true or false statement.
# you cannnot use "is" in conditional statement.
# Out:
# it is the same
# True
# True

# %% [markdown]
# ## CHALLENGES

# %% [markdown]
# #### Challenge 1

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
#     Enter a number: 4
#     Enter a number: 5
#     Enter a number: bad data
#     Invalid input
#     Enter a number: 7
#     Enter a number: done
#     16 3 5.333333333333333
#
# [PEW] E5.1

# %%
total = 0
count = 0

while True:
    num_input = input("Enter a number : ")

    if num_input == 'done':
        break

    try:
        num = int(num_input)
        total += num
        count += 1
    except ValueError:
        print("Invalid input.")
        continue

if count > 0:
    average = total / count
    #print("Total:", total)
    #print("Count:", count)
    #print("Average:", average)
    print( total, count, average)
else:
    print("No numbers entered.")
# Out:
# Enter a number : 4
# Enter a number : 5
# Enter a number : 7
# Enter a number : done
# 16 3 5.333333333333333

# %% [markdown]
# #### Challenge 2

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.
#
# [PEW] E5.2

# %%
numbers = []

while True:
  num_input = input("Enter a Number: ")

  if num_input == 'done':
    break

  try :
    num = int(num_input)
    numbers.append(num
                   )
  except ValueError:
    print("Invalid input")
    continue

  if numbers:
    maxnum = max(numbers)
    minnum = min(numbers)
    print("Maximum: ", maxnum)
    print("Minimum: ", minnum)
  else:
    print("No numbes Entered.7")
# Out:
# Maximum:  5
# Minimum:  5
# Invalid input
# Maximum:  5
# Minimum:  5
