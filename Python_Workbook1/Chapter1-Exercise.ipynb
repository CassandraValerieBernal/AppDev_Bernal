# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **EXERCISE 1**
#
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
Print('Hello world!') #the Print should be print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a31d47e7d7e1> in <cell line: 1>()
# ----> 1 Print('Hello world!') #the Print should be print
#
# NameError: name 'Print' is not defined

# %%
print('Hello world!') #the Print should be print - CORRECT CODE
# Out:
# Hello world!

# %%
print'Hello world!') #There is no open parenthesis
# Out:
#   File "<ipython-input-2-b603cde9c586>", line 1
#     print'Hello world!') #There is no open parenthesis
#                        ^
# SyntaxError: unmatched ')'

# %%
print('Hello world!') #There is no open parenthesis - CORRECT CODE
# Out:
# Hello world!

# %%
print('Hello world!) #There should be a qoute after the world
# Out:
#   File "<ipython-input-3-aa71a366f013>", line 1
#     print('Hello world!) #There should be a qoute after the world
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world!') #There should be a qoute after the world - CORRECT CODE
# Out:
# Hello world!

# %%
print('Hello world!'') #There is 2 qoutes after the world
# Out:
#   File "<ipython-input-4-fe81ad47b83e>", line 1
#     print('Hello world!'') #There is 2 qoutes after the world
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world!') #There is 2 qoutes after the world - CORRECT CODE

# %% [markdown]
# #**Exercise 2**
# What is the output of the code below?

# %%
x = 43
x = x + 1 #no error
print(x)
# Out:
# 44

# %% [markdown]
# #**Exercise 3**
# What is the output of the code below?

# %%
x = 43
x = X + 1 # X + 1 should be x +1
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-408296c60650> in <cell line: 2>()
#       1 x = 43
# ----> 2 x = X + 1 # X + 1 should be x +1
#       3 print(x)
#
# NameError: name 'X' is not defined

# %%
x = 43
x = x + 1 # X + 1 should be x +1  - CORRECT CODE
print(x)
# Out:
# 44
