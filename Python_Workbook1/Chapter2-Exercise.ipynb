# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colabnotebook_Bernal
# Out:
# /content/drive/MyDrive/Colabnotebook_Bernal

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Write a program that uses input to prompt a user for their name and then welcomes them.
# ```
# Enter your name: Chuck
# Hello Chuck
# ```
#
# [PEW] E2.2

# %%
name = input("Enter your name : ")
print('Hello', name)
# Out:
# Enter your name : cass
# Hello cass

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Write a program to prompt the user for hours and rate per hour to compute gross pay.
# ```
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25
# ```
#
# [PEW] E2.3

# %%
hours = float(input('Enter Hourse: '))
rate = float(input('Enter Rate : '))
pay = hours * rate
print('Pay :', pay)
# Out:
# Enter Hourse: 35
# Enter Rate : 2.75
# Pay : 96.25

# %% [markdown]
# #### Exercise 3

# %% [markdown]
# Assume that we execute the following assignment statements:
# ```python
# width = 17
# height = 12.0
# ```
# For each of the following expressions, write the value of the expression and the type (of the value of the expression).
# ```python
# width//2
# width/2.0
# height/3
# 1 + 2 * 5
# ```
#
# [PEW] E2.4

# %%
width = 17
height = 12.0


a = width//2
b = width/2.0
c = height/3
d = 1+2*5

print('Value of width//2 is  ', a , type(a))
print('Value of width/2.0 is  ', b , type(b))
print('Value of height/3 is  ', c , type(c))
print('Value of 1+2*5 is  ', d , type(d))
# Out:
# Value of width//2 is   8 <class 'int'>
# Value of width/2.0 is   8.5 <class 'float'>
# Value of height/3 is   4.0 <class 'float'>
# Value of 1+2*5 is   11 <class 'int'>

# %% [markdown]
# #### Exercise 4
#
# Write a program that uses input to prompt a user for a number and then outputs the square of the number
# ```
# Enter a number: 3
# The square of 3 is 9
# ```

# %%
num = int(input('Enter Number: '))
squared = num*num
print('the sqaure of ', num, 'is ', squared )
# Out:
# Enter Number: 5
# the sqaure of  5 is  25

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.
#
# [PEW] E2.5

# %%
cel = float(input('Enter Celsius Temperature: '))
fah = (cel * 9/5) + 32
print(cel, 'degrees celsius to', (fah))
# Out:
# Enter Celsius Temperature: 35
# 35.0 degrees celsius to 95.0
